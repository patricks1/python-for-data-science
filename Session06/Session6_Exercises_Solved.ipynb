# %% [markdown]
# # Python for Data Science, Level I
# ### *Session \#6*
# ---
#
# ### Helpful shortcuts
# ---
#
# **SHIFT** + **ENTER** ----> Execute Cell
#
# **TAB** ----> See autocomplete options
#
# **ESC** then **b** ----> Create Cell
#
# **ESC** then **dd** ----> Delete Cell
#
# **\[python expression\]?** ---> Explanation of that Python expression
#
# **ESC** then **m** then __ENTER__ ----> Switch to Markdown mode

# %% [markdown]
# ## I. Pandas Basics
#
# ### Warm Ups
#
# ---
#
# **Importing pandas:** `import pandas as pd`

# %%
import pandas as pd

# %% [markdown]
# **Dataframe from CSV:** `df = pd.read_csv("inspections.csv")`
#
# *Note: Input string can be a URL or a local file path*

# %%
df = pd.read_csv('https://github.com/patricks1/python-for-data-science/'
                 'raw/master/Session06/inspections.csv')

# %% [markdown]
# **First 5 lines of file:** `df.head()`

# %%
df.head()
# Out:
#       CAMIS                      DBA       BORO BUILDING    STREET  ZIPCODE  \
# 0  50058559            PRET A MANGER  MANHATTAN      299   7TH AVE  10001.0
# 1  50069855         FERRY HOUSE CAFE  MANHATTAN  PIER 11  SOUTH ST  10005.0
# 2  50072700              MAMA FINA'S  MANHATTAN      167  AVENUE A  10009.0
# 3  50047067  STARBUCKS COFFEE #22596   BROOKLYN      154  N 7TH ST  11249.0
# 4  41047349            JENNIFER CAFE  MANHATTAN       67  1 AVENUE  10003.0
#
#         PHONE                                CUISINE DESCRIPTION  \
# 0  6467280505                                           American
# 1  9175363918                                   CafÃ©/Coffee/Tea
# 2  9172620893                                           Filipino
# 3  7183840152                                   CafÃ©/Coffee/Tea
# 4  9176745443  Latin (Cuban, Dominican, Puerto Rican, South &...
#
#   INSPECTION DATE                                           ACTION  \
# 0      08/28/2017  Violations were cited in the following area(s).
# 1      11/30/2017  Violations were cited in the following area(s).
# 2      07/12/2018  Violations were cited in the following area(s).
# 3      07/21/2017  Violations were cited in the following area(s).
# 4      02/27/2018  Violations were cited in the following area(s).
#
#   VIOLATION CODE                              VIOLATION DESCRIPTION  \
# 0            16E  Caloric content range (minimum to maximum) not...
# 1            05H  No facilities available to wash, rinse and san...
# 2            04K  Evidence of rats or live rats present in facil...
# 3            16E  Caloric content range (minimum to maximum) not...
# 4            08A  Facility not vermin proof. Harborage or condit...
#
#   CRITICAL FLAG  SCORE GRADE  GRADE DATE RECORD DATE  \
# 0  Not Critical    NaN   NaN         NaN  04/01/2019
# 1      Critical   94.0     C  11/30/2017  04/01/2019
# 2      Critical    9.0     A  07/12/2018  04/01/2019
# 3  Not Critical    NaN   NaN         NaN  04/01/2019
# 4  Not Critical   20.0   NaN         NaN  04/01/2019
#
#                             INSPECTION TYPE
# 0      Calorie Posting / Initial Inspection
# 1  Pre-permit (Operational) / Re-inspection
# 2  Pre-permit (Operational) / Re-inspection
# 3      Calorie Posting / Initial Inspection
# 4     Cycle Inspection / Initial Inspection

# %%
df.loc[0]
# Out:
# CAMIS                                                             50058559
# DBA                                                          PRET A MANGER
# BORO                                                             MANHATTAN
# BUILDING                                                               299
# STREET                                                             7TH AVE
# ZIPCODE                                                            10001.0
# PHONE                                                           6467280505
# CUISINE DESCRIPTION                                               American
# INSPECTION DATE                                                 08/28/2017
# ACTION                     Violations were cited in the following area(s).
# VIOLATION CODE                                                         16E
# VIOLATION DESCRIPTION    Caloric content range (minimum to maximum) not...
# CRITICAL FLAG                                                 Not Critical
# SCORE                                                                  NaN
# GRADE                                                                  NaN
# GRADE DATE                                                             NaN
# RECORD DATE                                                     04/01/2019
# INSPECTION TYPE                       Calorie Posting / Initial Inspection
# Name: 0, dtype: object

# %% [markdown]
# **Boolean indexing on rows:** `df[df['GRADE'] == 'C']`

# %% [markdown]
# **Combining Boolean indexes:**
# ```python
# a_grade = df['GRADE'] == 'A'
# bk = df['BORO'] == 'BROOKLYN'
# df[a_grade & bk]
# ```

# %% [markdown]
# ## Exercises
# ---
# **1. Apply a Boolean filter to** `CUISINE DESCRIPTION` **to select only the Filipino restaurants. How many inspections were there?**
#
# Hint: Use the `len()` function.

# %%
filipino = df['CUISINE DESCRIPTION'] == "Filipino"

len(df[filipino])
# Out:
# 179

# %% [markdown]
# **2. Apply Boolean filters to select only rows where the** `CRITICAL FLAG` **column is** `Critical`. **What percentage of all inspections were** `Critical`**?**
#
# Hint: Divide the number of `Critical` rows by the total number

# %%
critical = df['CRITICAL FLAG'] == 'Critical'

len(df[critical]) / len(df)
# Out:
# 0.5447536292127646

# %% [markdown]
# **3. How many inspections are there for Starbucks? What percentage of Starbucks inspections were** `Critical`**?**
#
# Hint: Use the `DBA` column to target Starbucks

# %%
star = df['DBA'] == 'STARBUCKS'

len(df[star & critical]) / len(df[star])
# Out:
# 0.3354072398190045

# %% [markdown]
# **4. What percentage of inspections of restaurant located on either** `BOWERY` **or** `EAST BROADWAY` **streets were critical?**

# %%
bowery = df['STREET'] == 'BOWERY'
eb = df['STREET'] == 'EAST BROADWAY'

len(df[(bowery|eb)&critical]) / len(df[bowery|eb])
# Out:
# 0.5922014622258327

# %% [markdown]
# ### Extra Credit
# ---
# **1. Which type of restaurant has a higher percentage of** `Critical` **inspections -- restaurants with a** `CUISINE DESCRIPTION` **of** `'Donuts'` **or** `'Juice, Smoothies, Fruit Salads'`**?**

# %%
donuts = df['CUISINE DESCRIPTION'] == 'Donuts'
juice = df['CUISINE DESCRIPTION'] == 'Juice, Smoothies, Fruit Salads'

donut_ratio = len(df[donuts&critical])/len(df[donuts])
juice_ratio = len(df[juice&critical])/len(df[juice])

print("DONUT RATIO: " + str(donut_ratio))
print("JUICE RATIO: " + str(juice_ratio))
# Out:
# DONUT RATIO: 0.471031746031746
# JUICE RATIO: 0.5187202178352621

# %% [markdown]
# ## II. Columns
#
#
# ### Warm Ups
# ---
# **See column data types:** `df.dtypes`

# %%
df.dtypes
# Out:
# CAMIS                      int64
# DBA                       object
# BORO                      object
# BUILDING                  object
# STREET                    object
# ZIPCODE                  float64
# PHONE                     object
# CUISINE DESCRIPTION       object
# INSPECTION DATE           object
# ACTION                    object
# VIOLATION CODE            object
# VIOLATION DESCRIPTION     object
# CRITICAL FLAG             object
# SCORE                    float64
# GRADE                     object
# GRADE DATE                object
# RECORD DATE               object
# INSPECTION TYPE           object
# dtype: object

# %% [markdown]
# **Aggregate column with Numpy function:** `df['SCORE'].mean()`

# %% [markdown]
# **Create new column from existing one:** `df['NEG_SCORE'] = df['SCORE'] * -1`

# %% [markdown]
# **Create a dataframe from columns:**
# ```python
# columns = ['DBA', 'SCORE']
# df[columns]
# ```

# %%
columns = ['DBA', 'SCORE']
df[columns]
# Out:
#                             DBA  SCORE
# 0                 PRET A MANGER    NaN
# 1              FERRY HOUSE CAFE   94.0
# 2                   MAMA FINA'S    9.0
# 3       STARBUCKS COFFEE #22596    NaN
# 4                 JENNIFER CAFE   20.0
# ...                         ...    ...
# 250187         JUICE GENERATION    5.0
# 250188                COCO THAI   21.0
# 250189               MCDONALD'S    3.0
# 250190                 BY CHLOE   17.0
# 250191              ELDERGREENE   55.0
#
# [250192 rows x 2 columns]

# %% [markdown]
# **Sort dataframe ascending/descending based on column:**
# ```python
# df.sort_values('SCORE')
# df.sort_values('SCORE', ascending=False)
# ```

# %%
df.sort_values('SCORE')
# Out:
#            CAMIS                    DBA       BORO BUILDING            STREET  \
# 100835  41691451               ANGELINA  MANHATTAN       37          AVENUE A
# 125321  41677480    FUSION HK BAR-GRILL  MANHATTAN      688         10 AVENUE
# 76798   41702880  RAKU IT'S JAPANESE II  MANHATTAN       57  WEST   76 STREET
# 177692  41234821               GYU-KAKU  MANHATTAN       34     COOPER SQUARE
# 209819  50010285             FOOLS GOLD  MANHATTAN      145      E HOUSTON ST
# ...          ...                    ...        ...      ...               ...
# 250101  50061007               STEWARTS   BROOKLYN     8518           5TH AVE
# 250125  50053228            SUMNER CAFE   BROOKLYN      144        DECATUR ST
# 250163  50059003        VIVI BUBBLE TEA   BROOKLYN     2169           86TH ST
# 250165  50060875         EL CONDE NUEVO  MANHATTAN     4139          BROADWAY
# 250171  41002547             MCDONALD'S  MANHATTAN      972          6 AVENUE
#
#         ZIPCODE       PHONE             CUISINE DESCRIPTION INSPECTION DATE  \
# 100835  10009.0  2125337183                        American      09/24/2018
# 125321  10019.0  2129560185                         Mexican      10/24/2018
# 76798   10023.0  2128731220                        Japanese      07/24/2018
# 177692  10003.0  2124752989                        Japanese      06/02/2016
# 209819  10002.0  2126732337                        American      07/15/2015
# ...         ...         ...                             ...             ...
# 250101  11209.0  3474974357                        American      04/25/2018
# 250125  11233.0  3474046832                CafÃ©/Coffee/Tea      11/01/2016
# 250163  11214.0  7185326561  Juice, Smoothies, Fruit Salads      06/02/2018
# 250165  10033.0  2127810419                         Spanish      06/19/2018
# 250171  10018.0  2122792022                      Hamburgers      08/17/2017
#
#                                                    ACTION VIOLATION CODE  \
# 100835    Violations were cited in the following area(s).            10F
# 125321    Violations were cited in the following area(s).            06D
# 76798     Violations were cited in the following area(s).            02G
# 177692    Violations were cited in the following area(s).            06D
# 209819    Violations were cited in the following area(s).            08A
# ...                                                   ...            ...
# 250101  No violations were recorded at the time of thi...            NaN
# 250125  No violations were recorded at the time of thi...            NaN
# 250163    Violations were cited in the following area(s).            15F
# 250165    Violations were cited in the following area(s).            20F
# 250171    Violations were cited in the following area(s).            22C
#
#                                     VIOLATION DESCRIPTION   CRITICAL FLAG  \
# 100835  Non-food contact surface improperly constructe...    Not Critical
# 125321  Food contact surface not properly washed, rins...        Critical
# 76798   Cold food item held above 41Âº F (smoked fish ...        Critical
# 177692  Food contact surface not properly washed, rins...        Critical
# 209819  Facility not vermin proof. Harborage or condit...    Not Critical
# ...                                                   ...             ...
# 250101                                                NaN  Not Applicable
# 250125                                                NaN  Not Applicable
# 250163                                                NaN  Not Applicable
# 250165              Current letter grade card not posted.    Not Critical
# 250171  Bulb not shielded or shatterproof, in areas wh...    Not Critical
#
#         SCORE GRADE  GRADE DATE RECORD DATE  \
# 100835   -1.0   NaN         NaN  04/01/2019
# 125321   -1.0   NaN         NaN  04/01/2019
# 76798    -1.0     B  07/24/2018  04/01/2019
# 177692   -1.0   NaN         NaN  04/01/2019
# 209819   -1.0   NaN         NaN  04/01/2019
# ...       ...   ...         ...         ...
# 250101    NaN   NaN         NaN  04/01/2019
# 250125    NaN   NaN         NaN  04/01/2019
# 250163    NaN   NaN         NaN  04/01/2019
# 250165    NaN   NaN         NaN  04/01/2019
# 250171    NaN   NaN         NaN  04/01/2019
#
#                                           INSPECTION TYPE
# 100835              Cycle Inspection / Initial Inspection
# 125321              Cycle Inspection / Initial Inspection
# 76798                    Cycle Inspection / Re-inspection
# 177692              Cycle Inspection / Initial Inspection
# 209819              Cycle Inspection / Initial Inspection
# ...                                                   ...
# 250101  Administrative Miscellaneous / Initial Inspection
# 250125       Administrative Miscellaneous / Re-inspection
# 250163                 Smoke-Free Air Act / Re-inspection
# 250165  Administrative Miscellaneous / Initial Inspection
# 250171  Administrative Miscellaneous / Initial Inspection
#
# [250192 rows x 18 columns]

# %%
df.sort_values('SCORE', ascending=False)
# Out:
#            CAMIS                                DBA       BORO BUILDING  \
# 15551   41663270  NOUS LES AMIS RESTAURANT & BAKERY   BROOKLYN     2187
# 224785  41663270  NOUS LES AMIS RESTAURANT & BAKERY   BROOKLYN     2187
# 37837   41663270  NOUS LES AMIS RESTAURANT & BAKERY   BROOKLYN     2187
# 58920   41663270  NOUS LES AMIS RESTAURANT & BAKERY   BROOKLYN     2187
# 97876   41663270  NOUS LES AMIS RESTAURANT & BAKERY   BROOKLYN     2187
# ...          ...                                ...        ...      ...
# 250101  50061007                           STEWARTS   BROOKLYN     8518
# 250125  50053228                        SUMNER CAFE   BROOKLYN      144
# 250163  50059003                    VIVI BUBBLE TEA   BROOKLYN     2169
# 250165  50060875                     EL CONDE NUEVO  MANHATTAN     4139
# 250171  41002547                         MCDONALD'S  MANHATTAN      972
#
#                 STREET  ZIPCODE       PHONE             CUISINE DESCRIPTION  \
# 15551   CLARENDON ROAD  11226.0  3476279425                          Creole
# 224785  CLARENDON ROAD  11226.0  3476279425                          Creole
# 37837   CLARENDON ROAD  11226.0  3476279425                          Creole
# 58920   CLARENDON ROAD  11226.0  3476279425                          Creole
# 97876   CLARENDON ROAD  11226.0  3476279425                          Creole
# ...                ...      ...         ...                             ...
# 250101         5TH AVE  11209.0  3474974357                        American
# 250125      DECATUR ST  11233.0  3474046832                CafÃ©/Coffee/Tea
# 250163         86TH ST  11214.0  7185326561  Juice, Smoothies, Fruit Salads
# 250165        BROADWAY  10033.0  2127810419                         Spanish
# 250171        6 AVENUE  10018.0  2122792022                      Hamburgers
#
#        INSPECTION DATE                                             ACTION  \
# 15551       05/26/2018  Establishment Closed by DOHMH.  Violations wer...
# 224785      05/26/2018  Establishment Closed by DOHMH.  Violations wer...
# 37837       05/26/2018  Establishment Closed by DOHMH.  Violations wer...
# 58920       05/26/2018  Establishment Closed by DOHMH.  Violations wer...
# 97876       05/26/2018  Establishment Closed by DOHMH.  Violations wer...
# ...                ...                                                ...
# 250101      04/25/2018  No violations were recorded at the time of thi...
# 250125      11/01/2016  No violations were recorded at the time of thi...
# 250163      06/02/2018    Violations were cited in the following area(s).
# 250165      06/19/2018    Violations were cited in the following area(s).
# 250171      08/17/2017    Violations were cited in the following area(s).
#
#        VIOLATION CODE                              VIOLATION DESCRIPTION  \
# 15551             08A  Facility not vermin proof. Harborage or condit...
# 224785            02G  Cold food item held above 41Âº F (smoked fish ...
# 37837             06A  Personal cleanliness inadequate. Outer garment...
# 58920             06C  Food not protected from potential source of co...
# 97876             05F  Insufficient or no refrigerated or hot holding...
# ...               ...                                                ...
# 250101            NaN                                                NaN
# 250125            NaN                                                NaN
# 250163            15F                                                NaN
# 250165            20F              Current letter grade card not posted.
# 250171            22C  Bulb not shielded or shatterproof, in areas wh...
#
#          CRITICAL FLAG  SCORE GRADE GRADE DATE RECORD DATE  \
# 15551     Not Critical  156.0   NaN        NaN  04/01/2019
# 224785        Critical  156.0   NaN        NaN  04/01/2019
# 37837         Critical  156.0   NaN        NaN  04/01/2019
# 58920         Critical  156.0   NaN        NaN  04/01/2019
# 97876         Critical  156.0   NaN        NaN  04/01/2019
# ...                ...    ...   ...        ...         ...
# 250101  Not Applicable    NaN   NaN        NaN  04/01/2019
# 250125  Not Applicable    NaN   NaN        NaN  04/01/2019
# 250163  Not Applicable    NaN   NaN        NaN  04/01/2019
# 250165    Not Critical    NaN   NaN        NaN  04/01/2019
# 250171    Not Critical    NaN   NaN        NaN  04/01/2019
#
#                                           INSPECTION TYPE
# 15551               Cycle Inspection / Initial Inspection
# 224785              Cycle Inspection / Initial Inspection
# 37837               Cycle Inspection / Initial Inspection
# 58920               Cycle Inspection / Initial Inspection
# 97876               Cycle Inspection / Initial Inspection
# ...                                                   ...
# 250101  Administrative Miscellaneous / Initial Inspection
# 250125       Administrative Miscellaneous / Re-inspection
# 250163                 Smoke-Free Air Act / Re-inspection
# 250165  Administrative Miscellaneous / Initial Inspection
# 250171  Administrative Miscellaneous / Initial Inspection
#
# [250192 rows x 18 columns]

# %% [markdown]
# ### Exercises
# ---
# **1. Use** `.dtypes` **to check the datatype of the** `ZIPCODE` **column. Oh no! Since some ZIP codes start with a zero, this is not what we want.**
#
# **Load the data again using** `pd.read_csv()`, **but this time after the file name, give it an additional input of** `dtype={"ZIPCODE": str}` **to set the ZIP codes to a their proper type.**

# %%
df = pd.read_csv('https://github.com/patricks1/python-for-data-science/'
                 'raw/master/Session06/inspections.csv',
                 dtype={"ZIPCODE": str})

# %% [markdown]
# **2. What is the average** `SCORE` **across all inspections?**

# %%
df['SCORE'].mean()
# Out:
# 19.915540853345455

# %% [markdown]
# **3. Which has inspections with a higher average** `SCORE`, **Manhattan or Brooklyn?**

# %%
bk = df['BORO'] == 'BROOKLYN'
man = df['BORO'] == 'MANHATTAN'

df[man]['SCORE'].mean()
# Out:
# 19.758882986419728

# %% [markdown]
# **4. Create a new column** `SMALL_SCORE` **which takes the** `SCORE` **column and divides it by 10.**

# %%
df['SMALL_SCORE'] = df['SCORE'] / 10

# %% [markdown]
# **5. What is the most common** `STREET` **for inspections to occur on?**
#
# Hint: You can use the Numpy method `.mode()` to get the most frequently occuring value from a column.

# %%
df['STREET'].mode()
# Out:
# 0    BROADWAY
# Name: STREET, dtype: object

# %% [markdown]
# ### Extra Credit
# ---
# **6. What is the most common** `DBA` **for inspections that are flagged** `Critical`?

# %%
df[critical]['DBA'].mode()
# Out:
# 0    DUNKIN' DONUTS
# Name: DBA, dtype: object

# %% [markdown]
# ## III. Cleaning Data
#
#
# ### Warm Ups
# ---
#
# **Contains string:** `starbucks = df['DBA'].str.contains('STARBUCKS', na=False)`

# %%
starbucks = df['DBA'].str.contains('STARBUCKS', na=False)

# %% [markdown]
# **Starts/ends with:**
# ```python
# df['DBA'].str.startswith("THE")
# df['DBA'].str.endswith("RESTAURANT")
# ```

# %% [markdown]
# **Overwrite:** `df.loc[starbucks, "DBA"] = "STARBUCKS"`

# %%
df.loc[starbucks, 'DBA'] = 'STARBUCKS'

# %% [markdown]
# **Rows with/without NaN in column:**
# ```python
# df['GRADE'].isnull()
# df['GRADE'].notnull()
# ```

# %% [markdown]
# **Fill all NaN values in a column:** `df['GRADE'].fillna('NOT RATED')`

# %% [markdown]
# **Save to CSV:** `df.to_csv("inspections.csv", index=False)`

# %%
df.to_csv('inspections_mod.csv', index=False)

# %% [markdown]
# ### Exercises
# ---
# **1. Find all the spellings of McDonald's by filtering** `DBA` **to anything that contains** `DONALD`
#
# Hint: You can use the `set()` function on the `DBA` column after to just see unique values

# %%
donald = df['DBA'].str.contains('DONALD', na=False)

set(df[donald]['DBA'])
# Out:
# {'MCDONALD AVENUE DINER',
#  "MCDONALD'S",
#  "MCDONALD'S #11542",
#  "MCDONALD'S #13068",
#  "MCDONALD'S #23105",
#  "MCDONALD'S #3880",
#  "MCDONALD'S CORPORATION",
#  "MCDONALD'S RESTAURANT",
#  "MCDONALD'S RESTAURANTS OF NEW YORK INC",
#  'MCDONALDS',
#  'MCDONALDS # 18093',
#  'MCDONALDS # 6160',
#  'MCDONALDS RESTAURANT'}

# %% [markdown]
# **2. We don't want to include** `Macdonald Avenue Diner` **so create a second Boolean filter to matches** `DBA` **values that end with** `"DINER"`

# %%
ends_with_diner = df['DBA'].str.endswith('DINER', na=False)

safe_donald = ~ends_with_diner&donald

# %% [markdown]
# **3. Select the rows that match the** `DONALD` **filter but not the** `DINER` **filter, and overwrite with the string** `"MCDONALDS"` **to standardize the spelling.**

# %%
df.loc[safe_donald, 'DBA'] = "MCDONALDS"

# %% [markdown]
# **4. Use** `.fillna()` **to create a copy of the** `DBA` **column with an empty string instead of NAs. Overwrite the DBA column with this new version.**

# %%
df['DBA'] = df['DBA'].fillna('')

# %% [markdown]
# ### Extra Credit
# ---
#
# **1. Many restaurants without a grade were given an inspection score, which can be used to derive a grade. Those that get 0 and 13 points earn an A, those with 14 to 27 points receive a B and those with 28
# or more a C.**
#
# **Use boolean indexing to fill in those missing grades that can be derived.**

# %%
null_grade = df['GRADE'].isnull()

# Fill in A scores
a_score = df['SCORE'] < 14
should_be_a = null_grade & a_score
df.loc[should_be_a, 'GRADE'] = 'A'

# Fill in B scores
b_score = (14 <= df['SCORE']) & (df['SCORE'] <= 27)
should_be_b = null_grade & b_score
df.loc[should_be_b, 'GRADE'] = 'B'

# Fill in C scores
c_score = 28 < df['SCORE'] 
should_be_c = null_grade & c_score
df.loc[should_be_c, 'GRADE'] = 'C'

# %%
df[a_score & null_grade]
# Out:
#            CAMIS                        DBA       BORO BUILDING  \
# 24      50061061  KENNEDY'S CHICKEN & GRILL  MANHATTAN     2083
# 78      50047801             SUNFLOWER CAFE  MANHATTAN      676
# 82      50049976                    J-PETAL   BROOKLYN     4801
# 89      41632535        CROWN FRIED CHICKEN   BROOKLYN      456
# 98      50002502                    LE REVE  MANHATTAN      125
# ...          ...                        ...        ...      ...
# 250133  40935583      FRIED FRANK CAFETERIA  MANHATTAN        1
# 250136  41250519               MILANO'S BAR  MANHATTAN       51
# 250138  50077824           HARLEM ALE HOUSE  MANHATTAN      101
# 250143  50045961         TAI LAI RESTAURANT   BROOKLYN      990
# 250154  41101600                   EMPHASIS   BROOKLYN     6820
#
#                      STREET ZIPCODE       PHONE  \
# 24            AMSTERDAM AVE   10032  9176248039
# 78            AMSTERDAM AVE   10025  2127993415
# 82                  5TH AVE   11220  9179091862
# 89            SUTTER AVENUE   11212  7187084524
# 98                  E 54 ST   10022  2127597777
# ...                     ...     ...         ...
# 250133       NEW YORK PLAZA   10004  2128598041
# 250136  EAST HOUSTON STREET   10012  2122268844
# 250138           W 127TH ST   10027  3476410850
# 250143       T S BOYLAND ST     NaN  7184987787
# 250154             4 AVENUE   11220  7187481319
#
#                                       CUISINE DESCRIPTION INSPECTION DATE  \
# 24                                                Chicken      03/30/2017
# 78                                               American      01/05/2018
# 82                        Ice Cream, Gelato, Yogurt, Ices      06/03/2016
# 89                                                Chicken      08/21/2017
# 98                                         Middle Eastern      05/19/2018
# ...                                                   ...             ...
# 250133                                           American      08/08/2018
# 250136  Bottled beverages, including water, sodas, jui...      01/23/2017
# 250138                                           American      10/31/2018
# 250143                                            Chinese      09/15/2016
# 250154                                           American      09/11/2017
#
#                                                    ACTION VIOLATION CODE  \
# 24        Violations were cited in the following area(s).            10F
# 78      Establishment Closed by DOHMH.  Violations wer...            06C
# 82        Violations were cited in the following area(s).            06C
# 89        Violations were cited in the following area(s).            02B
# 98        Violations were cited in the following area(s).            06B
# ...                                                   ...            ...
# 250133    Violations were cited in the following area(s).            04N
# 250136    Violations were cited in the following area(s).            10F
# 250138    Violations were cited in the following area(s).            04N
# 250143    Violations were cited in the following area(s).            04M
# 250154    Violations were cited in the following area(s).            08A
#
#                                     VIOLATION DESCRIPTION CRITICAL FLAG  \
# 24      Non-food contact surface improperly constructe...  Not Critical
# 78      Food not protected from potential source of co...      Critical
# 82      Food not protected from potential source of co...      Critical
# 89            Hot food item not held at or above 140Âº F.      Critical
# 98      Tobacco use, eating, or drinking from open con...      Critical
# ...                                                   ...           ...
# 250133  Filth flies or food/refuse/sewage-associated (...      Critical
# 250136  Non-food contact surface improperly constructe...  Not Critical
# 250138  Filth flies or food/refuse/sewage-associated (...      Critical
# 250143  Live roaches present in facility's food and/or...      Critical
# 250154  Facility not vermin proof. Harborage or condit...  Not Critical
#
#         SCORE GRADE GRADE DATE RECORD DATE  \
# 24       13.0     A        NaN  04/01/2019
# 78       13.0     A        NaN  04/01/2019
# 82       10.0     A        NaN  04/01/2019
# 89       13.0     A        NaN  04/01/2019
# 98       12.0     A        NaN  04/01/2019
# ...       ...   ...        ...         ...
# 250133    8.0     A        NaN  04/01/2019
# 250136   11.0     A        NaN  04/01/2019
# 250138    8.0     A        NaN  04/01/2019
# 250143    8.0     A        NaN  04/01/2019
# 250154   11.0     A        NaN  04/01/2019
#
#                                           INSPECTION TYPE  SMALL_SCORE
# 24          Pre-permit (Operational) / Initial Inspection          1.3
# 78                  Cycle Inspection / Initial Inspection          1.3
# 82      Pre-permit (Non-operational) / Initial Inspection          1.0
# 89                  Cycle Inspection / Initial Inspection          1.3
# 98                  Cycle Inspection / Initial Inspection          1.2
# ...                                                   ...          ...
# 250133              Cycle Inspection / Initial Inspection          0.8
# 250136              Cycle Inspection / Initial Inspection          1.1
# 250138              Cycle Inspection / Initial Inspection          0.8
# 250143              Cycle Inspection / Initial Inspection          0.8
# 250154              Cycle Inspection / Initial Inspection          1.1
#
# [12649 rows x 19 columns]
